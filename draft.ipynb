# %%
import pandas as pd

# Đường dẫn tới file CSV vừa tạo
csv_path = r"C:\Users\PC\Desktop\Big data\Do_an_DS\Trien_khai_GUI\GUI_kmeans\data\rfm_data.csv"

# Đọc file CSV
df = pd.read_csv(csv_path)

# Hiển thị thông tin cơ bản
print("✅ File CSV đã load thành công!")
print("Số dòng:", len(df))
print("Các cột:", df.columns.tolist())

# Hiển thị 5 dòng đầu
df.head()
# Out:
# ✅ File CSV đã load thành công!
# Số dòng: 3898
# Các cột: ['Recency', 'Frequency', 'Monetary', 'R', 'F', 'M', 'RFM_Level', 'RFM_Score', 'Cluster']
#    Recency  Frequency  Monetary  R  F  M RFM_Level  RFM_Score  Cluster
# 0        3         31    375.31  4  4  4       VIP         12        2
# 1       91         27    361.45  3  4  4       VIP         11        2
# 2       26         25    345.10  4  4  4       VIP         12        2
# 3        4         29    334.15  4  4  4       VIP         12        2
# 4      142         17    312.46  2  4  4     LOYAL         10        2
